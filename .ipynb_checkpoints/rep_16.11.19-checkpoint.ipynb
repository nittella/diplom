# %%
import analisis_v3 as an

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
struct_104, struct_g104w3, struct_104oh6, struct_104oh6w6, struct_goh3, struct_gef3, struct_ghole1 = an.create_structures()
# Out:
# q25: 0.0 , q75: 5.0 threshold: 12.5

# %% [markdown]
# ## Water

# %%
an.make_sum_spectra([struct_104, struct_g104w3, struct_104oh6, struct_104oh6w6, struct_goh3, struct_gef3, struct_ghole1],
                 colorized_groups=['water_ANG_assignment', 'water_STRE_assignment'])
plt.legend()
plt.xticks([x for x in range(0, 4000, 100)])
plt.show()
